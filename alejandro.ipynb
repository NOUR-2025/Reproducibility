# %% [markdown]
# # Data Activity
#
# ---
#
# Created by Alejandro Ciuba (alejandrociuba@pitt.edu)
#
# ---
#
# ## Activity Layout
#
# Today, we will be doing some free-form data exploration with a dataset of your choosing! First, please go to [Kaggle](https://www.kaggle.com/datasets) and select a dataset; it can be any dataset you want.
#
# **MAKE SURE TO SAVE IT IN A SEPARATE DIRECTORY THAN THIS ONE!!!**
#
# Afterwards, please `git clone` this repository onto your computer.
#
# ---
#
# ## Instructions
#
# 1. Make a separate branch, naming it based on the dataset you chose.
#
#     **NOTE:** First, `cd` into the directory. Then, you run `git branch <NAME>` in the terminal to create the branch and `git checkout <NAME>` to switch to it.
# 2. Make a copy of this template, name it to reflect the dataset (also change the title).
# 3. Replace my name and email (Alejandro Ciuba) with your own.
# 4. Fill in the empty spaces in your Jupyter Notebook.
# 5. Create an Anaconda environment for this notebook.
# 6. Launch the environment.
# 7. Launch the notebok within the environment.
#
#     **NOTE:** This is done either through selecting the kernel in VSCode or running `jupyter <NAME>` after environment launch.
#
# From there, you are free to explore your data however you see fit! Make graphs, record anomalies, make connections. I recommend performing some statistical tests if you know them (although we'll cover those next week). Run `pip install <NAME>` for any packages you might need (e.g., [pandas](https://pandas.pydata.org/docs/), matplotlib, seaborn, etc.). Once we are finished, we will go over making an `environment.txt` file and forming pull requests.

# %% [markdown]
# ---
#
# ## Imports & Settings

# %%
# Put your imports here
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# Each code-block should be concise and accomplish one or two basic tasks
# %pprint  # Turn this off, let's you see more output

pd.set_option('display.max_columns', None)  # Output setting

plt.style.use('ggplot')  # I prefer this style for charts

sns.set_palette("muted")  # Set the colors for the charts

sns.color_palette("muted")  # Shows you what the color palette looks like
# Out:
# Pretty printing has been turned OFF
# [(0.2823529411764706, 0.47058823529411764, 0.8156862745098039), (0.9333333333333333, 0.5215686274509804, 0.2901960784313726), (0.41568627450980394, 0.8, 0.39215686274509803), (0.8392156862745098, 0.37254901960784315, 0.37254901960784315), (0.5843137254901961, 0.4235294117647059, 0.7058823529411765), (0.5490196078431373, 0.3803921568627451, 0.23529411764705882), (0.8627450980392157, 0.49411764705882355, 0.7529411764705882), (0.4745098039215686, 0.4745098039215686, 0.4745098039215686), (0.8352941176470589, 0.7333333333333333, 0.403921568627451), (0.5098039215686274, 0.7764705882352941, 0.8862745098039215)]

# %% [markdown]
# ---
#
# ## Functions

# %%
# Put any useful functions in their own codeblock here
def load_dataset(path: str) -> pd.DataFrame:
    return pd.read_csv(path)

# %%
def percentage_plot(df: pd.DataFrame, x: str, ordered: bool = False, labels: bool = False) -> plt.axes:

    ordering = df[x].value_counts().index

    plot = sns.countplot(data=df, x=x, hue=x, stat="percent", 
                         order=ordering if ordered else None, hue_order=ordering, palette=sns.color_palette("colorblind"))
    plot.tick_params(axis="x", rotation=90)
    plot.set_title(f"{x} Percentages")
    plot.set_ylabel("Percentage")
    plot.set_xlabel(x)
    plot.legend([], [], frameon=False)

    # Uncomment this if you want percentages over your bars
    # Bonus challenge: Rotate the labels vertically so they don't collide!
    # if labels:
    #     for c in plot.containers:
    #         plot.bar_label(c, fmt="%.2f")

    return plot

# %% [markdown]
# ---
# ## Globals

# %%
DATA = "../data/vgsales.csv"

# %% [markdown]
# ---
# ## Load Data

# %%
## Use Pandas to load your dataset
df = load_dataset(DATA)

# %%
## Use df.info() to get an overview
## Use df.describe() to get the data's descriptive statistics (mean, max/min, etc.)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# max       10.570000     82.740000

# %% [markdown]
# ---
#
# ## Data Exploration

# %%
## Explore your data here!

# %% [markdown]
# ---
#
# ### Year

# %%
# Look at year counts
percentage_plot(df, x='Year')
# Out:
# /tmp/ipykernel_208234/1138654774.py:5: UserWarning:
# The palette list has fewer values (10) than needed (39) and will cycle, which may produce an uninterpretable plot.
#   plot = sns.countplot(data=df, x=x, hue=x, stat="percent",
# <Axes: title={'center': 'Year Percentages'}, xlabel='Year', ylabel='Percentage'>

# %%
# Look at Genre distribution per year
g = sns.FacetGrid(df, col='Genre', col_wrap=4)

g.map(sns.countplot, 'Year', stat='percent')
g.tick_params(axis="x", rotation=90, labelsize=5)
# Out:
# /home/alejandro/miniconda3/envs/data-analysis/lib/python3.12/site-packages/seaborn/axisgrid.py:718: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# Look at Genre distribution per year
# TODO: Years are not organized
g = sns.FacetGrid(df, col='Platform', col_wrap=4)

g.map(sns.countplot, 'Year', stat='percent')
g.tick_params(axis="x", rotation=90, labelsize=5)
# Out:
# /home/alejandro/miniconda3/envs/data-analysis/lib/python3.12/site-packages/seaborn/axisgrid.py:718: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ---
#
# ### Publisher

# %%
# How many publishers?
len(df['Publisher'].unique())
# Out:
# 579

# %%
# Most prolific publisher?
df['Publisher'].value_counts().sort_values(ascending=False)
# Out:
# Publisher
# Electronic Arts                 1351
# Activision                       975
# Namco Bandai Games               932
# Ubisoft                          921
# Konami Digital Entertainment     832
#                                 ...
# Strategy First                     1
# Boost On                           1
# Interworks Unlimited, Inc.         1
# Genterprise                        1
# UIG Entertainment                  1
# Name: count, Length: 578, dtype: int64

# %%
# Get the top 5's data
top5 = df['Publisher'].value_counts().sort_values(ascending=False).iloc[0:5].index
top5
# Out:
# Index(['Electronic Arts', 'Activision', 'Namco Bandai Games', 'Ubisoft',
#        'Konami Digital Entertainment'],
#       dtype='object', name='Publisher')

# %%
sub_df = df[df['Publisher'].isin(top5)]

sub_df.sample(n=20)
# Out:
#         Rank                                           Name Platform    Year  \
# 9200    9202                                         Create     X360  2010.0
# 12808  12810                        Pro Yakyuu Famista 2011      3DS  2011.0
# 11512  11514                     Dragon Ball Z: Battle of Z     X360  2014.0
# 1026    1028                                      Overwatch      PS4  2016.0
# 10088  10090                    Queen's Blade: Spiral Chaos      PSP  2009.0
# 6750    6752                               Project Overkill       PS  1996.0
# 3633    3635                Metal Gear Solid 3: Subsistence      PS2  2005.0
# 10797  10799        Digimon Story: Super Xros Wars Blue/Red       DS  2011.0
# 1411    1413                        Need for Speed: The Run     X360  2011.0
# 1347    1349  LEGO Indiana Jones 2: The Adventure Continues      Wii  2009.0
# 10582  10584                         Guitar Hero: Van Halen      PS2  2009.0
# 9859    9861     Wallace & Gromit: Curse of the Were-Rabbit      PS2  2005.0
# 2985    2987              Prince of Persia: The Two Thrones      PS2  2005.0
# 12142  12144                       Tony Hawk's Pro Skater 5     X360  2015.0
# 11050  11052             Batman Beyond: Return of the Joker      N64  2000.0
# 6342    6344                            NBA In The Zone '98      N64  1997.0
# 16437  16440          The Cages: Pro Style Batting Practice      Wii  2010.0
# 334      335                               FIFA Soccer 2005      PS2  2004.0
# 3058    3060                      Tiger Woods PGA Tour 2000       PS  1998.0
# 16292  16295                                      Surf's Up       GC  2007.0
#
#               Genre                     Publisher  NA_Sales  EU_Sales  \
# 9200         Action               Electronic Arts      0.10      0.03
# 12808        Sports            Namco Bandai Games      0.00      0.00
# 11512      Fighting            Namco Bandai Games      0.01      0.06
# 1026        Shooter                    Activision      0.64      0.68
# 10088  Role-Playing            Namco Bandai Games      0.00      0.00
# 6750        Shooter  Konami Digital Entertainment      0.14      0.09
# 3633         Action  Konami Digital Entertainment      0.34      0.01
# 10797  Role-Playing            Namco Bandai Games      0.00      0.00
# 1411         Action               Electronic Arts      0.63      0.58
# 1347         Action                    Activision      0.91      0.39
# 10582          Misc                    Activision      0.05      0.04
# 9859      Adventure  Konami Digital Entertainment      0.06      0.05
# 2985         Action                       Ubisoft      0.57      0.02
# 12142        Sports                    Activision      0.06      0.00
# 11050        Action                       Ubisoft      0.07      0.02
# 6342         Sports  Konami Digital Entertainment      0.25      0.02
# 16437        Sports  Konami Digital Entertainment      0.01      0.00
# 334          Sports               Electronic Arts      0.58      2.48
# 3058         Sports               Electronic Arts      0.37      0.25
# 16292        Sports                       Ubisoft      0.01      0.00
#
#        JP_Sales  Other_Sales  Global_Sales
# 9200       0.00         0.01          0.14
# 12808      0.06         0.00          0.06
# 11512      0.00         0.01          0.08
# 1026       0.14         0.26          1.73
# 10088      0.11         0.00          0.11
# 6750       0.00         0.02          0.25
# 3633       0.15         0.06          0.55
# 10797      0.10         0.00          0.10
# 1411       0.00         0.15          1.38
# 1347       0.00         0.13          1.43
# 10582      0.00         0.01          0.10
# 9859       0.00         0.02          0.12
# 2985       0.00         0.09          0.68
# 12142      0.00         0.01          0.07
# 11050      0.00         0.00          0.09
# 6342       0.00         0.00          0.27
# 16437      0.00         0.00          0.01
# 334        0.04         0.59          3.70
# 3058       0.00         0.04          0.66
# 16292      0.00         0.00          0.01

# %%
g = sns.FacetGrid(sub_df, col='Publisher')
g.map(sns.countplot, 'Year', stat='percent')
g.tick_params(axis="x", rotation=90, labelsize=5)
# Out:
# /home/alejandro/miniconda3/envs/data-analysis/lib/python3.12/site-packages/seaborn/axisgrid.py:718: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g = sns.FacetGrid(sub_df, col='Publisher')
g.map(sns.barplot, 'Year', 'Global_Sales', errorbar=None)
g.tick_params(axis="x", rotation=90, labelsize=5)
# Out:
# /home/alejandro/miniconda3/envs/data-analysis/lib/python3.12/site-packages/seaborn/axisgrid.py:718: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# Each company's best selling titles
# TODO: Fix this
sub_df.groupby(['Publisher'])['Global_Sales'].nlargest(n=3)
# Out:
# Publisher
# Activision                    29     14.76
#                               31     14.64
#                               33     14.24
# Electronic Arts               77      8.49
#                               82      8.24
#                               83      8.11
# Konami Digital Entertainment  142     6.05
#                               144     6.03
#                               145     6.03
# Namco Bandai Games            264     4.24
#                               294     4.05
#                               302     3.98
# Ubisoft                       60     10.26
#                               68      9.52
#                               102     7.27
# Name: Global_Sales, dtype: float64
